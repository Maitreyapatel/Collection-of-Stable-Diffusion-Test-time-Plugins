# %%
import os
import pickle
import numpy as np

import cv2
import matplotlib.pyplot as plt

# %%
with open("../data/vg_owlvit_regions.pkl", "rb") as h:
    data = pickle.load(h)

# %%
plt.imshow(data[2]['regions'][0]['region_mask'])
